# %%
import dst.dst as dst
import matplotlib.pyplot as plt
from dst import tools
# Out:
# Eager execution: True

# %%
# Set up some global values here
content_path = '/tmp/nst/Green_Sea_Turtle_grazing_seagrass.jpg'
style_path = '/tmp/nst/The_Great_Wave_off_Kanagawa.jpg'

plt.figure(figsize=(10,10))

content = tools._load_image(content_path).astype('uint8')
style = tools._load_image(style_path).astype('uint8')

plt.subplot(1, 2, 1)
tools.imshow(content, 'Content Image')

plt.subplot(1, 2, 2)
tools.imshow(style, 'Style Image')
plt.show()

# %%
st = dst()
# Out:
# Python version: 3.6
# TensoFlow version:  1.13.1
# Keras version:  2.2.4-tf

# %%
best, best_loss = st.tranfer_style(content_path, 
                                     style_path, num_iter=60)

# %%
def show_results(best_img, content_path, style_path, show_large_final=True):
    plt.figure(figsize=(10, 5))
    content = tools._load_image(content_path) 
    style = tools._load_image(style_path)

    plt.subplot(1, 2, 1)
    tools.imshow(content, 'Content Image')

    plt.subplot(1, 2, 2)
    tools.imshow(style, 'Style Image')

    if show_large_final: 
        plt.figure(figsize=(10, 10))

        plt.imshow(best_img)
        plt.title('Output Image')
    plt.show()

# %%
show_results(best, content_path, style_path)
