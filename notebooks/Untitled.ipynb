# %%
import sys
sys.path.append("..")

# %%
CONTENT = "https://cdn.pixabay.com/photo/2016/10/27/22/53/heart-1776746_960_720.jpg"
STYLE = "../images/style.jpg"

# %%
from dst import dst
from dst import  tools

# %%
img = tools._open_image(CONTENT,url=True)

# %%
img = tools._scale_image(img, 1000)

# %%
img = tools._image_to_array(img)

# %%
tools.imshow(img, "URL")

# %%
my_dst = dst()
# Out:
# Python version: 3.7
# TensoFlow version:  1.13.1
# Keras version:  2.2.4-tf

# %%
vgg = dst._get_vgg19()
# Out:
# WARNING:tensorflow:From /home/martin/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
vgg = dst._freeze_layers(vgg)

# %%
layers = my_dst._get_layers(vgg)

# %%
cont, sty = tools.load_images(CONTENT, STYLE)

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(sty)
tools.get_image_dim(sty)
# Out:
# (4000, 6000, 3)
