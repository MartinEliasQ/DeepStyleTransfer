# %%
import sys
sys.path.append("..")

# %%
CONTENT = "../images/perfil.jpg"
STYLE = "../images/perfil.jpg"

# %%
from dst import dst
from dst import  tools

# %%
img = tools._open_image(CONTENT)

# %%
img = tools._scale_image(img, 1000)

# %%
img = tools._image_to_array(img)

# %%
tools.imshow(img, "URL")

# %%
my_dst = dst()
# Out:
# Python version: 3.7
# TensoFlow version:  1.13.1
# Keras version:  2.2.4-tf

# %%
# Content layer where will pull our feature maps
content_layers = ['block5_conv2'] 

# Style layer we are interested in
style_layers = ['block1_conv1',
                'block2_conv1',
                'block3_conv1', 
                'block4_conv1', 
                'block5_conv1'
               ]

num_content_layers = len(content_layers)
num_style_layers = len(style_layers)

# %%
model = my_dst.get_model(content_layers, style_layers)
# Out:
# WARNING:tensorflow:From /home/martin/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, None, None, 3)     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, None, None, 128)   0
# ...

# %%
dst._get_feactuere_maps(model, CONTENT, STYLE, num_style_layers)
# Out:
# ([<tf.Tensor 'model/block1_conv1/Relu:0' shape=(1, 512, 230, 64) dtype=float32>,
#   <tf.Tensor 'model/block2_conv1/Relu:0' shape=(1, 256, 115, 128) dtype=float32>,
#   <tf.Tensor 'model/block3_conv1/Relu:0' shape=(1, 128, 57, 256) dtype=float32>,
#   <tf.Tensor 'model/block4_conv1/Relu:0' shape=(1, 64, 28, 512) dtype=float32>,
#   <tf.Tensor 'model/block5_conv1/Relu:0' shape=(1, 32, 14, 512) dtype=float32>],
#  [<tf.Tensor 'model_1/block5_conv2/Relu:0' shape=(1, 32, 14, 512) dtype=float32>])

# %%
dst.tranfer_style(CONTENT,STYLE)
# Out:
# ../images/perfil.jpg ../images/perfil.jpg ['block5_conv2'] ['block1_conv1', 'block2_conv1', 'block3_conv1', 'block4_conv1', 'block5_conv1'] 100000.0 0.001 1000 None
# [<tf.Tensor 'model_1_1/block1_conv1/Relu:0' shape=(1, 512, 230, 64) dtype=float32>, <tf.Tensor 'model_1_1/block2_conv1/Relu:0' shape=(1, 256, 115, 128) dtype=float32>, <tf.Tensor 'model_1_1/block3_conv1/Relu:0' shape=(1, 128, 57, 256) dtype=float32>, <tf.Tensor 'model_1_1/block4_conv1/Relu:0' shape=(1, 64, 28, 512) dtype=float32>, <tf.Tensor 'model_1_1/block5_conv1/Relu:0' shape=(1, 32, 14, 512) dtype=float32>]
# [<tf.Tensor 'model_1_2/block5_conv2/Relu:0' shape=(1, 32, 14, 512) dtype=float32>]
